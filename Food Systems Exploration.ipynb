# %%
import matplotlib

# %%
import tweepy

# %%
import pandas as pd

# %%
import os

# %%
token = 'AAAAAAAAAAAAAAAAAAAAANCChgEAAAAAVe5rD7dN%2BlvyuA4i1vs2fkL%2Fxak%3DpeY1WnKraxNlsQwTPfWxNzrI0WYRQeVluOksBN0mPuKDVEZO51'

# %%
client = tweepy.Client(token)

# %%
query = "food system"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)

# %%
count_list = []
for resp in responses:
    count_list.extend(resp.data)

# %%
df3 = pd.DataFrame(count_list)

# %%
df3['start'] = pd.to_datetime(df3['start'])
df3 = df3.set_index('start')

# %%
df3.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-06-16 00:00:00+00:00  2020-06-17T00:00:00.000Z        40488
# 2020-12-29 00:00:00+00:00  2020-12-30T00:00:00.000Z        33258
# 2020-06-17 00:00:00+00:00  2020-06-18T00:00:00.000Z        28438
# 2020-09-07 00:00:00+00:00  2020-09-08T00:00:00.000Z        27774
# 2020-12-28 00:00:00+00:00  2020-12-29T00:00:00.000Z        18474
# ...                                             ...          ...
# 2020-02-02 00:00:00+00:00  2020-02-03T00:00:00.000Z          859
# 2020-01-12 00:00:00+00:00  2020-01-13T00:00:00.000Z          844
# 2020-02-22 00:00:00+00:00  2020-02-23T00:00:00.000Z          791
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z          715
# 2020-01-11 00:00:00+00:00  2020-01-12T00:00:00.000Z          647
#
# [366 rows x 2 columns]

# %%
query = "food systems"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df4 = pd.DataFrame(count_list)
df4['start'] = pd.to_datetime(df4['start'])
df4 = df4.set_index('start')
df4.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-10-16 00:00:00+00:00  2020-10-17T00:00:00.000Z         6685
# 2020-10-14 00:00:00+00:00  2020-10-15T00:00:00.000Z         6020
# 2020-10-15 00:00:00+00:00  2020-10-16T00:00:00.000Z         4092
# 2020-04-10 00:00:00+00:00  2020-04-11T00:00:00.000Z         2445
# 2020-04-23 00:00:00+00:00  2020-04-24T00:00:00.000Z         2347
# ...                                             ...          ...
# 2020-01-04 00:00:00+00:00  2020-01-05T00:00:00.000Z          235
# 2020-02-02 00:00:00+00:00  2020-02-03T00:00:00.000Z          234
# 2020-02-16 00:00:00+00:00  2020-02-17T00:00:00.000Z          202
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z          167
# 2020-01-05 00:00:00+00:00  2020-01-06T00:00:00.000Z          155
#
# [366 rows x 2 columns]

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df5 = pd.DataFrame(count_list)
df5['start'] = pd.to_datetime(df5['start'])
df5 = df5.set_index('start')
df5.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-10-16 00:00:00+00:00  2020-10-17T00:00:00.000Z         6685
# 2020-10-14 00:00:00+00:00  2020-10-15T00:00:00.000Z         6020
# 2020-10-15 00:00:00+00:00  2020-10-16T00:00:00.000Z         4092
# 2020-04-10 00:00:00+00:00  2020-04-11T00:00:00.000Z         2445
# 2020-04-23 00:00:00+00:00  2020-04-24T00:00:00.000Z         2348
# ...                                             ...          ...
# 2020-01-04 00:00:00+00:00  2020-01-05T00:00:00.000Z          235
# 2020-02-02 00:00:00+00:00  2020-02-03T00:00:00.000Z          234
# 2020-02-16 00:00:00+00:00  2020-02-17T00:00:00.000Z          202
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z          167
# 2020-01-05 00:00:00+00:00  2020-01-06T00:00:00.000Z          155
#
# [366 rows x 2 columns]

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2019-01-01T00:00:00Z',
                                 end_time='2020-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df5 = pd.DataFrame(count_list)
df5['start'] = pd.to_datetime(df5['start'])
df5 = df5.set_index('start')
df5.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2019-10-16 00:00:00+00:00  2019-10-17T00:00:00.000Z         1952
# 2019-05-22 00:00:00+00:00  2019-05-23T00:00:00.000Z         1810
# 2019-08-09 00:00:00+00:00  2019-08-10T00:00:00.000Z         1414
# 2019-05-08 00:00:00+00:00  2019-05-09T00:00:00.000Z         1391
# 2019-10-15 00:00:00+00:00  2019-10-16T00:00:00.000Z         1359
# ...                                             ...          ...
# 2019-06-15 00:00:00+00:00  2019-06-16T00:00:00.000Z          170
# 2019-05-26 00:00:00+00:00  2019-05-27T00:00:00.000Z          169
# 2019-03-24 00:00:00+00:00  2019-03-25T00:00:00.000Z          168
# 2019-04-21 00:00:00+00:00  2019-04-22T00:00:00.000Z          168
# 2019-12-25 00:00:00+00:00  2019-12-26T00:00:00.000Z          157
#
# [365 rows x 2 columns]

# %%
query = "food system"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df6 = pd.DataFrame(count_list)
df6['start'] = pd.to_datetime(df6['start'])
df6 = df6.set_index('start')
df6.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-01-28 00:00:00+00:00  2021-01-29T00:00:00.000Z        10993
# 2021-07-20 00:00:00+00:00  2021-07-21T00:00:00.000Z         8458
# 2021-01-27 00:00:00+00:00  2021-01-28T00:00:00.000Z         7579
# 2021-04-10 00:00:00+00:00  2021-04-11T00:00:00.000Z         6601
# 2021-05-19 00:00:00+00:00  2021-05-20T00:00:00.000Z         6379
# ...                                             ...          ...
# 2021-12-24 00:00:00+00:00  2021-12-25T00:00:00.000Z          961
# 2021-02-14 00:00:00+00:00  2021-02-15T00:00:00.000Z          958
# 2021-12-19 00:00:00+00:00  2021-12-20T00:00:00.000Z          952
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z          908
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z          639
#
# [365 rows x 2 columns]

# %%
token = 'AAAAAAAAAAAAAAAAAAAAANCChgEAAAAAVe5rD7dN%2BlvyuA4i1vs2fkL%2Fxak%3DpeY1WnKraxNlsQwTPfWxNzrI0WYRQeVluOksBN0mPuKDVEZO51'

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-04-22 00:00:00+00:00  2021-04-23T00:00:00.000Z        57159
# 2021-05-05 00:00:00+00:00  2021-05-06T00:00:00.000Z        53003
# 2021-03-22 00:00:00+00:00  2021-03-23T00:00:00.000Z        49777
# 2021-10-13 00:00:00+00:00  2021-10-14T00:00:00.000Z        48429
# 2021-04-21 00:00:00+00:00  2021-04-22T00:00:00.000Z        39390
# ...                                             ...          ...
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z         6330
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z         5648
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z         5013
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z         4931
# 2021-01-03 00:00:00+00:00  2021-01-04T00:00:00.000Z         4920
#
# [365 rows x 2 columns]

# %%
query = "food system"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-01-28 00:00:00+00:00  2021-01-29T00:00:00.000Z        10997
# 2021-07-20 00:00:00+00:00  2021-07-21T00:00:00.000Z         8454
# 2021-01-27 00:00:00+00:00  2021-01-28T00:00:00.000Z         7575
# 2021-04-10 00:00:00+00:00  2021-04-11T00:00:00.000Z         6613
# 2021-05-19 00:00:00+00:00  2021-05-20T00:00:00.000Z         6376
# ...                                             ...          ...
# 2021-12-24 00:00:00+00:00  2021-12-25T00:00:00.000Z          961
# 2021-02-14 00:00:00+00:00  2021-02-15T00:00:00.000Z          958
# 2021-12-19 00:00:00+00:00  2021-12-20T00:00:00.000Z          952
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z          908
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z          639
#
# [365 rows x 2 columns]

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-06-16 00:00:00+00:00  2020-06-17T00:00:00.000Z        40459
# 2020-12-29 00:00:00+00:00  2020-12-30T00:00:00.000Z        33254
# 2020-06-17 00:00:00+00:00  2020-06-18T00:00:00.000Z        28423
# 2020-09-07 00:00:00+00:00  2020-09-08T00:00:00.000Z        27767
# 2020-12-28 00:00:00+00:00  2020-12-29T00:00:00.000Z        18470
# ...                                             ...          ...
# 2020-02-02 00:00:00+00:00  2020-02-03T00:00:00.000Z          858
# 2020-01-12 00:00:00+00:00  2020-01-13T00:00:00.000Z          844
# 2020-02-22 00:00:00+00:00  2020-02-23T00:00:00.000Z          791
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z          715
# 2020-01-11 00:00:00+00:00  2020-01-12T00:00:00.000Z          648
#
# [366 rows x 2 columns]

# %%
query = "food systems"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-08-12 00:00:00+00:00  2021-08-13T00:00:00.000Z         9961
# 2021-09-23 00:00:00+00:00  2021-09-24T00:00:00.000Z         9944
# 2021-06-21 00:00:00+00:00  2021-06-22T00:00:00.000Z         7356
# 2021-07-23 00:00:00+00:00  2021-07-24T00:00:00.000Z         7216
# 2021-06-22 00:00:00+00:00  2021-06-23T00:00:00.000Z         7034
# ...                                             ...          ...
# 2021-12-19 00:00:00+00:00  2021-12-20T00:00:00.000Z          312
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z          306
# 2021-12-24 00:00:00+00:00  2021-12-25T00:00:00.000Z          302
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z          301
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z          246
#
# [365 rows x 2 columns]

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-10-16 00:00:00+00:00  2020-10-17T00:00:00.000Z         6687
# 2020-10-14 00:00:00+00:00  2020-10-15T00:00:00.000Z         6024
# 2020-10-15 00:00:00+00:00  2020-10-16T00:00:00.000Z         4087
# 2020-04-10 00:00:00+00:00  2020-04-11T00:00:00.000Z         2444
# 2020-04-23 00:00:00+00:00  2020-04-24T00:00:00.000Z         2348
# ...                                             ...          ...
# 2020-02-02 00:00:00+00:00  2020-02-03T00:00:00.000Z          234
# 2020-01-04 00:00:00+00:00  2020-01-05T00:00:00.000Z          234
# 2020-02-16 00:00:00+00:00  2020-02-17T00:00:00.000Z          202
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z          166
# 2020-01-05 00:00:00+00:00  2020-01-06T00:00:00.000Z          155
#
# [366 rows x 2 columns]

# %%
query = "food system"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2019-01-01T00:00:00Z',
                                 end_time='2020-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2019-07-11 00:00:00+00:00  2019-07-12T00:00:00.000Z        10318
# 2019-06-18 00:00:00+00:00  2019-06-19T00:00:00.000Z         7169
# 2019-10-17 00:00:00+00:00  2019-10-18T00:00:00.000Z         5731
# 2019-04-04 00:00:00+00:00  2019-04-05T00:00:00.000Z         3477
# 2019-01-24 00:00:00+00:00  2019-01-25T00:00:00.000Z         3402
# ...                                             ...          ...
# 2019-08-31 00:00:00+00:00  2019-09-01T00:00:00.000Z          622
# 2019-09-01 00:00:00+00:00  2019-09-02T00:00:00.000Z          609
# 2019-05-26 00:00:00+00:00  2019-05-27T00:00:00.000Z          599
# 2019-02-17 00:00:00+00:00  2019-02-18T00:00:00.000Z          575
# 2019-01-01 00:00:00+00:00  2019-01-02T00:00:00.000Z          491
#
# [365 rows x 2 columns]

# %%
query = "sustainability"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2019-01-01T00:00:00Z',
                                 end_time='2020-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2019-10-29 00:00:00+00:00  2019-10-30T00:00:00.000Z        35070
# 2019-04-03 00:00:00+00:00  2019-04-04T00:00:00.000Z        24950
# 2019-04-04 00:00:00+00:00  2019-04-05T00:00:00.000Z        23948
# 2019-07-19 00:00:00+00:00  2019-07-20T00:00:00.000Z        21567
# 2019-04-22 00:00:00+00:00  2019-04-23T00:00:00.000Z        21280
# ...                                             ...          ...
# 2019-09-01 00:00:00+00:00  2019-09-02T00:00:00.000Z         4387
# 2019-06-16 00:00:00+00:00  2019-06-17T00:00:00.000Z         4303
# 2019-08-04 00:00:00+00:00  2019-08-05T00:00:00.000Z         4137
# 2019-01-01 00:00:00+00:00  2019-01-02T00:00:00.000Z         3960
# 2019-12-25 00:00:00+00:00  2019-12-26T00:00:00.000Z         3379
#
# [365 rows x 2 columns]

# %%
query = "agribusiness"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2019-01-01T00:00:00Z',
                                 end_time='2020-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2019-08-22 00:00:00+00:00  2019-08-23T00:00:00.000Z        51125
# 2019-08-23 00:00:00+00:00  2019-08-24T00:00:00.000Z        18914
# 2019-08-21 00:00:00+00:00  2019-08-22T00:00:00.000Z        11504
# 2019-01-03 00:00:00+00:00  2019-01-04T00:00:00.000Z         6086
# 2019-08-24 00:00:00+00:00  2019-08-25T00:00:00.000Z         5933
# ...                                             ...          ...
# 2019-02-03 00:00:00+00:00  2019-02-04T00:00:00.000Z          315
# 2019-12-15 00:00:00+00:00  2019-12-16T00:00:00.000Z          304
# 2019-06-02 00:00:00+00:00  2019-06-03T00:00:00.000Z          303
# 2019-04-14 00:00:00+00:00  2019-04-15T00:00:00.000Z          294
# 2019-12-25 00:00:00+00:00  2019-12-26T00:00:00.000Z          262
#
# [365 rows x 2 columns]

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-08-26 00:00:00+00:00  2020-08-27T00:00:00.000Z         2694
# 2020-10-30 00:00:00+00:00  2020-10-31T00:00:00.000Z         2642
# 2020-05-26 00:00:00+00:00  2020-05-27T00:00:00.000Z         2468
# 2020-08-20 00:00:00+00:00  2020-08-21T00:00:00.000Z         2424
# 2020-09-25 00:00:00+00:00  2020-09-26T00:00:00.000Z         2082
# ...                                             ...          ...
# 2020-12-25 00:00:00+00:00  2020-12-26T00:00:00.000Z          257
# 2020-03-22 00:00:00+00:00  2020-03-23T00:00:00.000Z          239
# 2020-01-12 00:00:00+00:00  2020-01-13T00:00:00.000Z          227
# 2020-12-26 00:00:00+00:00  2020-12-27T00:00:00.000Z          212
# 2020-03-21 00:00:00+00:00  2020-03-22T00:00:00.000Z          199
#
# [366 rows x 2 columns]

# %%
import pandas as pd
import os
import tweepy
token = 'AAAAAAAAAAAAAAAAAAAAANCChgEAAAAAVe5rD7dN%2BlvyuA4i1vs2fkL%2Fxak%3DpeY1WnKraxNlsQwTPfWxNzrI0WYRQeVluOksBN0mPuKDVEZO51'

# %%
client = tweepy.Client(token)

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-06-16 00:00:00+00:00  2020-06-17T00:00:00.000Z        40083
# 2020-12-29 00:00:00+00:00  2020-12-30T00:00:00.000Z        32912
# 2020-06-17 00:00:00+00:00  2020-06-18T00:00:00.000Z        28195
# 2020-09-07 00:00:00+00:00  2020-09-08T00:00:00.000Z        27502
# 2020-12-28 00:00:00+00:00  2020-12-29T00:00:00.000Z        18315
# ...                                             ...          ...
# 2020-02-02 00:00:00+00:00  2020-02-03T00:00:00.000Z          850
# 2020-01-12 00:00:00+00:00  2020-01-13T00:00:00.000Z          841
# 2020-02-22 00:00:00+00:00  2020-02-23T00:00:00.000Z          784
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z          709
# 2020-01-11 00:00:00+00:00  2020-01-12T00:00:00.000Z          642
#
# [366 rows x 2 columns]

# %%
query = "nutrition"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-09-07 00:00:00+00:00  2020-09-08T00:00:00.000Z        23927
# 2020-07-28 00:00:00+00:00  2020-07-29T00:00:00.000Z        22675
# 2020-03-14 00:00:00+00:00  2020-03-15T00:00:00.000Z        22102
# 2020-02-17 00:00:00+00:00  2020-02-18T00:00:00.000Z        22059
# 2020-01-18 00:00:00+00:00  2020-01-19T00:00:00.000Z        21724
# ...                                             ...          ...
# 2020-12-19 00:00:00+00:00  2020-12-20T00:00:00.000Z         5592
# 2020-11-08 00:00:00+00:00  2020-11-09T00:00:00.000Z         5574
# 2020-11-01 00:00:00+00:00  2020-11-02T00:00:00.000Z         5559
# 2020-12-20 00:00:00+00:00  2020-12-21T00:00:00.000Z         5243
# 2020-12-25 00:00:00+00:00  2020-12-26T00:00:00.000Z         4701
#
# [366 rows x 2 columns]

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-03-01 00:00:00+00:00  2021-03-02T00:00:00.000Z        30908
# 2021-09-06 00:00:00+00:00  2021-09-07T00:00:00.000Z        21225
# 2021-09-10 00:00:00+00:00  2021-09-11T00:00:00.000Z        20412
# 2021-02-27 00:00:00+00:00  2021-02-28T00:00:00.000Z        20129
# 2021-09-09 00:00:00+00:00  2021-09-10T00:00:00.000Z        18672
# ...                                             ...          ...
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z         5959
# 2021-12-19 00:00:00+00:00  2021-12-20T00:00:00.000Z         5916
# 2021-04-04 00:00:00+00:00  2021-04-05T00:00:00.000Z         5784
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z         5194
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z         5119
#
# [365 rows x 2 columns]

# %%
query = "food system"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-06-16 00:00:00+00:00  2020-06-17T00:00:00.000Z        38878
# 2020-12-29 00:00:00+00:00  2020-12-30T00:00:00.000Z        31895
# 2020-06-17 00:00:00+00:00  2020-06-18T00:00:00.000Z        27268
# 2020-09-07 00:00:00+00:00  2020-09-08T00:00:00.000Z        26281
# 2020-12-28 00:00:00+00:00  2020-12-29T00:00:00.000Z        17720
# ...                                             ...          ...
# 2020-02-02 00:00:00+00:00  2020-02-03T00:00:00.000Z          823
# 2020-01-12 00:00:00+00:00  2020-01-13T00:00:00.000Z          812
# 2020-02-22 00:00:00+00:00  2020-02-23T00:00:00.000Z          757
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z          694
# 2020-01-11 00:00:00+00:00  2020-01-12T00:00:00.000Z          617
#
# [366 rows x 2 columns]

# %%
query = "agriculture"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-05-13 00:00:00+00:00  2020-05-14T00:00:00.000Z       156200
# 2020-05-26 00:00:00+00:00  2020-05-27T00:00:00.000Z       139302
# 2020-09-20 00:00:00+00:00  2020-09-21T00:00:00.000Z        77513
# 2020-09-25 00:00:00+00:00  2020-09-26T00:00:00.000Z        60619
# 2020-09-21 00:00:00+00:00  2020-09-22T00:00:00.000Z        57432
# ...                                             ...          ...
# 2020-01-05 00:00:00+00:00  2020-01-06T00:00:00.000Z         7502
# 2020-02-09 00:00:00+00:00  2020-02-10T00:00:00.000Z         7396
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z         7174
# 2020-03-14 00:00:00+00:00  2020-03-15T00:00:00.000Z         6330
# 2020-03-15 00:00:00+00:00  2020-03-16T00:00:00.000Z         5463
#
# [366 rows x 2 columns]

# %%
query = "greenhouse gas"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-09-17 00:00:00+00:00  2020-09-18T00:00:00.000Z         5033
# 2020-09-23 00:00:00+00:00  2020-09-24T00:00:00.000Z         4243
# 2020-06-16 00:00:00+00:00  2020-06-17T00:00:00.000Z         3323
# 2020-01-15 00:00:00+00:00  2020-01-16T00:00:00.000Z         3183
# 2020-01-16 00:00:00+00:00  2020-01-17T00:00:00.000Z         3081
# ...                                             ...          ...
# 2020-03-22 00:00:00+00:00  2020-03-23T00:00:00.000Z          297
# 2020-04-19 00:00:00+00:00  2020-04-20T00:00:00.000Z          296
# 2020-07-05 00:00:00+00:00  2020-07-06T00:00:00.000Z          289
# 2020-05-10 00:00:00+00:00  2020-05-11T00:00:00.000Z          265
# 2020-05-31 00:00:00+00:00  2020-06-01T00:00:00.000Z          213
#
# [366 rows x 2 columns]

# %%
df7['tweet_count'].plot()
# Out:
# <AxesSubplot: xlabel='start'>

# %%
query = "nutrition"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-09-07 00:00:00+00:00  2020-09-08T00:00:00.000Z        23928
# 2020-07-28 00:00:00+00:00  2020-07-29T00:00:00.000Z        22677
# 2020-03-14 00:00:00+00:00  2020-03-15T00:00:00.000Z        22107
# 2020-02-17 00:00:00+00:00  2020-02-18T00:00:00.000Z        22060
# 2020-01-18 00:00:00+00:00  2020-01-19T00:00:00.000Z        21729
# ...                                             ...          ...
# 2020-12-19 00:00:00+00:00  2020-12-20T00:00:00.000Z         5592
# 2020-11-08 00:00:00+00:00  2020-11-09T00:00:00.000Z         5574
# 2020-11-01 00:00:00+00:00  2020-11-02T00:00:00.000Z         5560
# 2020-12-20 00:00:00+00:00  2020-12-21T00:00:00.000Z         5243
# 2020-12-25 00:00:00+00:00  2020-12-26T00:00:00.000Z         4700
#
# [366 rows x 2 columns]

# %%
df7['tweet_count'].plot()
# Out:
# <AxesSubplot: xlabel='start'>

# %%
query = "food system"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-06-16 00:00:00+00:00  2020-06-17T00:00:00.000Z        38883
# 2020-12-29 00:00:00+00:00  2020-12-30T00:00:00.000Z        31892
# 2020-06-17 00:00:00+00:00  2020-06-18T00:00:00.000Z        27263
# 2020-09-07 00:00:00+00:00  2020-09-08T00:00:00.000Z        26275
# 2020-12-28 00:00:00+00:00  2020-12-29T00:00:00.000Z        17720
# ...                                             ...          ...
# 2020-02-02 00:00:00+00:00  2020-02-03T00:00:00.000Z          823
# 2020-01-12 00:00:00+00:00  2020-01-13T00:00:00.000Z          812
# 2020-02-22 00:00:00+00:00  2020-02-23T00:00:00.000Z          757
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z          694
# 2020-01-11 00:00:00+00:00  2020-01-12T00:00:00.000Z          617
#
# [366 rows x 2 columns]

# %%
df7['tweet_count'].plot()
# Out:
# <AxesSubplot: xlabel='start'>

# %%
query = "agriculture"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-05-13 00:00:00+00:00  2020-05-14T00:00:00.000Z       156201
# 2020-05-26 00:00:00+00:00  2020-05-27T00:00:00.000Z       139303
# 2020-09-20 00:00:00+00:00  2020-09-21T00:00:00.000Z        77511
# 2020-09-25 00:00:00+00:00  2020-09-26T00:00:00.000Z        60621
# 2020-09-21 00:00:00+00:00  2020-09-22T00:00:00.000Z        57432
# ...                                             ...          ...
# 2020-01-05 00:00:00+00:00  2020-01-06T00:00:00.000Z         7502
# 2020-02-09 00:00:00+00:00  2020-02-10T00:00:00.000Z         7396
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z         7174
# 2020-03-14 00:00:00+00:00  2020-03-15T00:00:00.000Z         6330
# 2020-03-15 00:00:00+00:00  2020-03-16T00:00:00.000Z         5463
#
# [366 rows x 2 columns]

# %%
df7['tweet_count'].plot()
# Out:
# <AxesSubplot: xlabel='start'>

# %%
query = "hunger"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-08-23 00:00:00+00:00  2020-08-24T00:00:00.000Z       239434
# 2020-10-22 00:00:00+00:00  2020-10-23T00:00:00.000Z        94868
# 2020-06-02 00:00:00+00:00  2020-06-03T00:00:00.000Z        88724
# 2020-08-26 00:00:00+00:00  2020-08-27T00:00:00.000Z        85609
# 2020-08-22 00:00:00+00:00  2020-08-23T00:00:00.000Z        78084
# ...                                             ...          ...
# 2020-01-25 00:00:00+00:00  2020-01-26T00:00:00.000Z        10892
# 2020-02-29 00:00:00+00:00  2020-03-01T00:00:00.000Z        10852
# 2020-02-01 00:00:00+00:00  2020-02-02T00:00:00.000Z        10694
# 2020-02-08 00:00:00+00:00  2020-02-09T00:00:00.000Z        10503
# 2020-01-01 00:00:00+00:00  2020-01-02T00:00:00.000Z        10243
#
# [366 rows x 2 columns]

# %%
df7['tweet_count'].plot()
# Out:
# <AxesSubplot: xlabel='start'>

# %%
query = "climate change"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2020-09-15 00:00:00+00:00  2020-09-16T00:00:00.000Z       306261
# 2020-09-30 00:00:00+00:00  2020-10-01T00:00:00.000Z       241836
# 2020-10-08 00:00:00+00:00  2020-10-09T00:00:00.000Z       214595
# 2020-01-06 00:00:00+00:00  2020-01-07T00:00:00.000Z       206889
# 2020-09-10 00:00:00+00:00  2020-09-11T00:00:00.000Z       193415
# ...                                             ...          ...
# 2020-12-26 00:00:00+00:00  2020-12-27T00:00:00.000Z        14230
# 2020-05-31 00:00:00+00:00  2020-06-01T00:00:00.000Z        13708
# 2020-06-13 00:00:00+00:00  2020-06-14T00:00:00.000Z        13060
# 2020-12-24 00:00:00+00:00  2020-12-25T00:00:00.000Z        12931
# 2020-12-25 00:00:00+00:00  2020-12-26T00:00:00.000Z         9278
#
# [366 rows x 2 columns]

# %%
df7['tweet_count'].plot()
# Out:
# <AxesSubplot: xlabel='start'>

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2020-01-01T00:00:00Z',
                                 end_time='2021-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)

# %%
query = "health"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-01-28 00:00:00+00:00  2021-01-29T00:00:00.000Z       928729
# 2021-09-02 00:00:00+00:00  2021-09-03T00:00:00.000Z       920689
# 2021-07-28 00:00:00+00:00  2021-07-29T00:00:00.000Z       720756
# 2021-09-10 00:00:00+00:00  2021-09-11T00:00:00.000Z       699649
# 2021-04-07 00:00:00+00:00  2021-04-08T00:00:00.000Z       659016
# ...                                             ...          ...
# 2021-11-13 00:00:00+00:00  2021-11-14T00:00:00.000Z       300989
# 2021-11-14 00:00:00+00:00  2021-11-15T00:00:00.000Z       300883
# 2021-10-30 00:00:00+00:00  2021-10-31T00:00:00.000Z       299457
# 2021-02-14 00:00:00+00:00  2021-02-15T00:00:00.000Z       292428
# 2021-10-31 00:00:00+00:00  2021-11-01T00:00:00.000Z       265719
#
# [365 rows x 2 columns]

# %%
query = "environment"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-06-05 00:00:00+00:00  2021-06-06T00:00:00.000Z       383983
# 2021-04-22 00:00:00+00:00  2021-04-23T00:00:00.000Z       192150
# 2021-10-26 00:00:00+00:00  2021-10-27T00:00:00.000Z       129272
# 2021-08-09 00:00:00+00:00  2021-08-10T00:00:00.000Z       123751
# 2021-11-09 00:00:00+00:00  2021-11-10T00:00:00.000Z       123201
# ...                                             ...          ...
# 2021-05-02 00:00:00+00:00  2021-05-03T00:00:00.000Z        41816
# 2021-05-09 00:00:00+00:00  2021-05-10T00:00:00.000Z        38942
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z        37833
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z        34148
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z        33870
#
# [365 rows x 2 columns]

# %%
query = "deforestation"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-11-02 00:00:00+00:00  2021-11-03T00:00:00.000Z        38686
# 2021-11-03 00:00:00+00:00  2021-11-04T00:00:00.000Z        19148
# 2021-11-19 00:00:00+00:00  2021-11-20T00:00:00.000Z        13675
# 2021-11-17 00:00:00+00:00  2021-11-18T00:00:00.000Z        13103
# 2021-11-04 00:00:00+00:00  2021-11-05T00:00:00.000Z        11828
# ...                                             ...          ...
# 2021-01-31 00:00:00+00:00  2021-02-01T00:00:00.000Z         1320
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z         1274
# 2021-01-03 00:00:00+00:00  2021-01-04T00:00:00.000Z         1224
# 2021-01-07 00:00:00+00:00  2021-01-08T00:00:00.000Z         1207
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z          584
#
# [365 rows x 2 columns]

# %%
query = "biodiversity"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-05-22 00:00:00+00:00  2021-05-23T00:00:00.000Z        79908
# 2021-09-10 00:00:00+00:00  2021-09-11T00:00:00.000Z        62955
# 2021-06-11 00:00:00+00:00  2021-06-12T00:00:00.000Z        53042
# 2021-06-26 00:00:00+00:00  2021-06-27T00:00:00.000Z        39575
# 2021-08-31 00:00:00+00:00  2021-09-01T00:00:00.000Z        32557
# ...                                             ...          ...
# 2021-05-02 00:00:00+00:00  2021-05-03T00:00:00.000Z         2852
# 2021-01-03 00:00:00+00:00  2021-01-04T00:00:00.000Z         2334
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z         2305
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z         2305
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z         1930
#
# [365 rows x 2 columns]

# %%
query = "climate change"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-11-02 00:00:00+00:00  2021-11-03T00:00:00.000Z       305094
# 2021-11-01 00:00:00+00:00  2021-11-02T00:00:00.000Z       269837
# 2021-08-09 00:00:00+00:00  2021-08-10T00:00:00.000Z       258259
# 2021-08-10 00:00:00+00:00  2021-08-11T00:00:00.000Z       211329
# 2021-09-02 00:00:00+00:00  2021-09-03T00:00:00.000Z       207201
# ...                                             ...          ...
# 2021-05-08 00:00:00+00:00  2021-05-09T00:00:00.000Z        20642
# 2021-03-07 00:00:00+00:00  2021-03-08T00:00:00.000Z        20134
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z        19889
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z        18822
# 2021-05-09 00:00:00+00:00  2021-05-10T00:00:00.000Z        16682
#
# [365 rows x 2 columns]

# %%
query = "hunger"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-09-29 00:00:00+00:00  2021-09-30T00:00:00.000Z       116037
# 2021-11-01 00:00:00+00:00  2021-11-02T00:00:00.000Z       103662
# 2021-11-02 00:00:00+00:00  2021-11-03T00:00:00.000Z       101161
# 2021-09-14 00:00:00+00:00  2021-09-15T00:00:00.000Z        89244
# 2021-05-19 00:00:00+00:00  2021-05-20T00:00:00.000Z        86444
# ...                                             ...          ...
# 2021-08-22 00:00:00+00:00  2021-08-23T00:00:00.000Z        15429
# 2021-06-20 00:00:00+00:00  2021-06-21T00:00:00.000Z        15373
# 2021-08-24 00:00:00+00:00  2021-08-25T00:00:00.000Z        15159
# 2021-06-02 00:00:00+00:00  2021-06-03T00:00:00.000Z        14666
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z        12254
#
# [365 rows x 2 columns]

# %%
query = "malnutrition"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-09-13 00:00:00+00:00  2021-09-14T00:00:00.000Z        41006
# 2021-09-12 00:00:00+00:00  2021-09-13T00:00:00.000Z        35026
# 2021-09-29 00:00:00+00:00  2021-09-30T00:00:00.000Z        21710
# 2021-09-15 00:00:00+00:00  2021-09-16T00:00:00.000Z        20788
# 2021-02-21 00:00:00+00:00  2021-02-22T00:00:00.000Z        14351
# ...                                             ...          ...
# 2021-05-16 00:00:00+00:00  2021-05-17T00:00:00.000Z          743
# 2021-03-21 00:00:00+00:00  2021-03-22T00:00:00.000Z          733
# 2021-02-06 00:00:00+00:00  2021-02-07T00:00:00.000Z          647
# 2021-04-04 00:00:00+00:00  2021-04-05T00:00:00.000Z          572
# 2021-04-17 00:00:00+00:00  2021-04-18T00:00:00.000Z          447
#
# [365 rows x 2 columns]

# %%
query = "nutrition"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-03-01 00:00:00+00:00  2021-03-02T00:00:00.000Z        30891
# 2021-09-06 00:00:00+00:00  2021-09-07T00:00:00.000Z        21165
# 2021-09-10 00:00:00+00:00  2021-09-11T00:00:00.000Z        20385
# 2021-02-27 00:00:00+00:00  2021-02-28T00:00:00.000Z        20043
# 2021-09-09 00:00:00+00:00  2021-09-10T00:00:00.000Z        18658
# ...                                             ...          ...
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z         5941
# 2021-12-19 00:00:00+00:00  2021-12-20T00:00:00.000Z         5905
# 2021-04-04 00:00:00+00:00  2021-04-05T00:00:00.000Z         5776
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z         5177
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z         5109
#
# [365 rows x 2 columns]

# %%
query = "sustainability"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-04-22 00:00:00+00:00  2021-04-23T00:00:00.000Z        54967
# 2021-05-05 00:00:00+00:00  2021-05-06T00:00:00.000Z        50999
# 2021-03-22 00:00:00+00:00  2021-03-23T00:00:00.000Z        48041
# 2021-10-13 00:00:00+00:00  2021-10-14T00:00:00.000Z        46802
# 2021-04-21 00:00:00+00:00  2021-04-22T00:00:00.000Z        38058
# ...                                             ...          ...
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z         6133
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z         5444
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z         4846
# 2021-01-03 00:00:00+00:00  2021-01-04T00:00:00.000Z         4741
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z         4715
#
# [365 rows x 2 columns]

# %%
query = "food sovereignty"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-05-20 00:00:00+00:00  2021-05-21T00:00:00.000Z         1254
# 2021-09-24 00:00:00+00:00  2021-09-25T00:00:00.000Z         1199
# 2021-07-01 00:00:00+00:00  2021-07-02T00:00:00.000Z         1009
# 2021-09-23 00:00:00+00:00  2021-09-24T00:00:00.000Z          895
# 2021-08-08 00:00:00+00:00  2021-08-09T00:00:00.000Z          684
# ...                                             ...          ...
# 2021-05-09 00:00:00+00:00  2021-05-10T00:00:00.000Z           40
# 2021-12-23 00:00:00+00:00  2021-12-24T00:00:00.000Z           36
# 2021-05-08 00:00:00+00:00  2021-05-09T00:00:00.000Z           34
# 2021-12-27 00:00:00+00:00  2021-12-28T00:00:00.000Z           30
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z           29
#
# [365 rows x 2 columns]

# %%
query = "food insecurity"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-11-30 00:00:00+00:00  2021-12-01T00:00:00.000Z         9102
# 2021-04-22 00:00:00+00:00  2021-04-23T00:00:00.000Z         7259
# 2021-10-20 00:00:00+00:00  2021-10-21T00:00:00.000Z         6078
# 2021-05-19 00:00:00+00:00  2021-05-20T00:00:00.000Z         5937
# 2021-12-01 00:00:00+00:00  2021-12-02T00:00:00.000Z         5796
# ...                                             ...          ...
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z          612
# 2021-06-06 00:00:00+00:00  2021-06-07T00:00:00.000Z          594
# 2021-05-16 00:00:00+00:00  2021-05-17T00:00:00.000Z          547
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z          506
# 2021-07-04 00:00:00+00:00  2021-07-05T00:00:00.000Z          506
#
# [365 rows x 2 columns]

# %%
query = "fair trade"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-09-03 00:00:00+00:00  2021-09-04T00:00:00.000Z       102685
# 2021-09-04 00:00:00+00:00  2021-09-05T00:00:00.000Z        30449
# 2021-01-11 00:00:00+00:00  2021-01-12T00:00:00.000Z        24984
# 2021-09-05 00:00:00+00:00  2021-09-06T00:00:00.000Z         8602
# 2021-09-08 00:00:00+00:00  2021-09-09T00:00:00.000Z         7639
# ...                                             ...          ...
# 2021-08-21 00:00:00+00:00  2021-08-22T00:00:00.000Z          621
# 2021-07-04 00:00:00+00:00  2021-07-05T00:00:00.000Z          604
# 2021-08-15 00:00:00+00:00  2021-08-16T00:00:00.000Z          554
# 2021-08-14 00:00:00+00:00  2021-08-15T00:00:00.000Z          532
# 2021-04-04 00:00:00+00:00  2021-04-05T00:00:00.000Z          530
#
# [365 rows x 2 columns]

# %%
query = "pesticide"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-01-09 00:00:00+00:00  2021-01-10T00:00:00.000Z        36137
# 2021-01-10 00:00:00+00:00  2021-01-11T00:00:00.000Z        31874
# 2021-01-11 00:00:00+00:00  2021-01-12T00:00:00.000Z        12506
# 2021-08-19 00:00:00+00:00  2021-08-20T00:00:00.000Z         5945
# 2021-08-18 00:00:00+00:00  2021-08-19T00:00:00.000Z         4894
# ...                                             ...          ...
# 2021-12-24 00:00:00+00:00  2021-12-25T00:00:00.000Z          305
# 2021-12-31 00:00:00+00:00  2022-01-01T00:00:00.000Z          292
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z          269
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z          210
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z          184
#
# [365 rows x 2 columns]

# %%
query = "greenhouse gas"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-07-12 00:00:00+00:00  2021-07-13T00:00:00.000Z        20526
# 2021-04-22 00:00:00+00:00  2021-04-23T00:00:00.000Z        19276
# 2021-08-09 00:00:00+00:00  2021-08-10T00:00:00.000Z        17468
# 2021-07-11 00:00:00+00:00  2021-07-12T00:00:00.000Z        15581
# 2021-04-23 00:00:00+00:00  2021-04-24T00:00:00.000Z        11407
# ...                                             ...          ...
# 2021-04-04 00:00:00+00:00  2021-04-05T00:00:00.000Z          549
# 2021-07-10 00:00:00+00:00  2021-07-11T00:00:00.000Z          544
# 2021-05-30 00:00:00+00:00  2021-05-31T00:00:00.000Z          544
# 2021-06-12 00:00:00+00:00  2021-06-13T00:00:00.000Z          501
# 2021-12-31 00:00:00+00:00  2022-01-01T00:00:00.000Z          482
#
# [365 rows x 2 columns]

# %%
query = "food waste"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-08-13 00:00:00+00:00  2021-08-14T00:00:00.000Z       129759
# 2021-02-12 00:00:00+00:00  2021-02-13T00:00:00.000Z        52258
# 2021-08-14 00:00:00+00:00  2021-08-15T00:00:00.000Z        46466
# 2021-01-31 00:00:00+00:00  2021-02-01T00:00:00.000Z        38530
# 2021-01-19 00:00:00+00:00  2021-01-20T00:00:00.000Z        34862
# ...                                             ...          ...
# 2021-11-28 00:00:00+00:00  2021-11-29T00:00:00.000Z         1014
# 2021-12-04 00:00:00+00:00  2021-12-05T00:00:00.000Z         1004
# 2021-08-21 00:00:00+00:00  2021-08-22T00:00:00.000Z          962
# 2021-07-04 00:00:00+00:00  2021-07-05T00:00:00.000Z          870
# 2021-09-12 00:00:00+00:00  2021-09-13T00:00:00.000Z          801
#
# [365 rows x 2 columns]

# %%
query = "labor right"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-09-06 00:00:00+00:00  2021-09-07T00:00:00.000Z        11418
# 2021-10-16 00:00:00+00:00  2021-10-17T00:00:00.000Z        11184
# 2021-03-10 00:00:00+00:00  2021-03-11T00:00:00.000Z         8389
# 2021-04-18 00:00:00+00:00  2021-04-19T00:00:00.000Z         7842
# 2021-10-23 00:00:00+00:00  2021-10-24T00:00:00.000Z         6608
# ...                                             ...          ...
# 2021-12-31 00:00:00+00:00  2022-01-01T00:00:00.000Z          430
# 2021-11-28 00:00:00+00:00  2021-11-29T00:00:00.000Z          388
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z          375
# 2021-02-20 00:00:00+00:00  2021-02-21T00:00:00.000Z          362
# 2021-01-03 00:00:00+00:00  2021-01-04T00:00:00.000Z          357
#
# [365 rows x 2 columns]

# %%
query = "animal welfare"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-11-07 00:00:00+00:00  2021-11-08T00:00:00.000Z        12300
# 2021-06-16 00:00:00+00:00  2021-06-17T00:00:00.000Z         9297
# 2021-06-15 00:00:00+00:00  2021-06-16T00:00:00.000Z         8072
# 2021-10-15 00:00:00+00:00  2021-10-16T00:00:00.000Z         7921
# 2021-08-20 00:00:00+00:00  2021-08-21T00:00:00.000Z         7714
# ...                                             ...          ...
# 2021-02-14 00:00:00+00:00  2021-02-15T00:00:00.000Z          678
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z          674
# 2021-01-17 00:00:00+00:00  2021-01-18T00:00:00.000Z          621
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z          611
# 2021-12-05 00:00:00+00:00  2021-12-06T00:00:00.000Z          599
#
# [365 rows x 2 columns]

# %%
query = "industrial agriculture"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-07-15 00:00:00+00:00  2021-07-16T00:00:00.000Z         2591
# 2021-07-16 00:00:00+00:00  2021-07-17T00:00:00.000Z         1458
# 2021-03-19 00:00:00+00:00  2021-03-20T00:00:00.000Z         1228
# 2021-11-17 00:00:00+00:00  2021-11-18T00:00:00.000Z         1043
# 2021-08-07 00:00:00+00:00  2021-08-08T00:00:00.000Z          850
# ...                                             ...          ...
# 2021-01-09 00:00:00+00:00  2021-01-10T00:00:00.000Z           59
# 2021-06-19 00:00:00+00:00  2021-06-20T00:00:00.000Z           57
# 2021-05-15 00:00:00+00:00  2021-05-16T00:00:00.000Z           54
# 2021-04-01 00:00:00+00:00  2021-04-02T00:00:00.000Z           40
# 2021-12-25 00:00:00+00:00  2021-12-26T00:00:00.000Z           28
#
# [365 rows x 2 columns]

# %%
query = "organic agriculture"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-06-11 00:00:00+00:00  2021-06-12T00:00:00.000Z         3996
# 2021-11-09 00:00:00+00:00  2021-11-10T00:00:00.000Z         1736
# 2021-01-26 00:00:00+00:00  2021-01-27T00:00:00.000Z         1503
# 2021-11-10 00:00:00+00:00  2021-11-11T00:00:00.000Z         1232
# 2021-08-09 00:00:00+00:00  2021-08-10T00:00:00.000Z         1106
# ...                                             ...          ...
# 2021-04-03 00:00:00+00:00  2021-04-04T00:00:00.000Z           64
# 2021-01-10 00:00:00+00:00  2021-01-11T00:00:00.000Z           61
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z           56
# 2021-12-26 00:00:00+00:00  2021-12-27T00:00:00.000Z           56
# 2021-04-04 00:00:00+00:00  2021-04-05T00:00:00.000Z           46
#
# [365 rows x 2 columns]

# %%
query = "sustainable agriculture"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-06-11 00:00:00+00:00  2021-06-12T00:00:00.000Z         4324
# 2021-01-28 00:00:00+00:00  2021-01-29T00:00:00.000Z         3411
# 2021-02-26 00:00:00+00:00  2021-02-27T00:00:00.000Z         1724
# 2021-02-27 00:00:00+00:00  2021-02-28T00:00:00.000Z         1350
# 2021-11-02 00:00:00+00:00  2021-11-03T00:00:00.000Z         1284
# ...                                             ...          ...
# 2021-11-28 00:00:00+00:00  2021-11-29T00:00:00.000Z          113
# 2021-10-03 00:00:00+00:00  2021-10-04T00:00:00.000Z          113
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z           94
# 2021-01-03 00:00:00+00:00  2021-01-04T00:00:00.000Z           89
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z           66
#
# [365 rows x 2 columns]

# %%
query = "food price"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-06-12 00:00:00+00:00  2021-06-13T00:00:00.000Z        16065
# 2021-02-18 00:00:00+00:00  2021-02-19T00:00:00.000Z         9403
# 2021-04-26 00:00:00+00:00  2021-04-27T00:00:00.000Z         8877
# 2021-11-12 00:00:00+00:00  2021-11-13T00:00:00.000Z         8680
# 2021-09-21 00:00:00+00:00  2021-09-22T00:00:00.000Z         8497
# ...                                             ...          ...
# 2021-01-01 00:00:00+00:00  2021-01-02T00:00:00.000Z          660
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z          652
# 2021-01-31 00:00:00+00:00  2021-02-01T00:00:00.000Z          650
# 2021-03-20 00:00:00+00:00  2021-03-21T00:00:00.000Z          642
# 2021-05-15 00:00:00+00:00  2021-05-16T00:00:00.000Z          618
#
# [365 rows x 2 columns]

# %%
query = "sustainable farming"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-01-15 00:00:00+00:00  2021-01-16T00:00:00.000Z         3608
# 2021-01-02 00:00:00+00:00  2021-01-03T00:00:00.000Z         3265
# 2021-11-13 00:00:00+00:00  2021-11-14T00:00:00.000Z         2242
# 2021-03-22 00:00:00+00:00  2021-03-23T00:00:00.000Z         2171
# 2021-12-02 00:00:00+00:00  2021-12-03T00:00:00.000Z         1582
# ...                                             ...          ...
# 2021-12-19 00:00:00+00:00  2021-12-20T00:00:00.000Z          132
# 2021-06-20 00:00:00+00:00  2021-06-21T00:00:00.000Z          129
# 2021-06-19 00:00:00+00:00  2021-06-20T00:00:00.000Z          121
# 2021-12-24 00:00:00+00:00  2021-12-25T00:00:00.000Z          109
# 2021-08-07 00:00:00+00:00  2021-08-08T00:00:00.000Z          105
#
# [365 rows x 2 columns]

# %%
query = "food shortage"

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='day'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
#                                                 end  tweet_count
# start
# 2021-09-24 00:00:00+00:00  2021-09-25T00:00:00.000Z         7893
# 2021-04-24 00:00:00+00:00  2021-04-25T00:00:00.000Z         7813
# 2021-09-01 00:00:00+00:00  2021-09-02T00:00:00.000Z         7450
# 2021-09-22 00:00:00+00:00  2021-09-23T00:00:00.000Z         6958
# 2021-09-15 00:00:00+00:00  2021-09-16T00:00:00.000Z         6589
# ...                                             ...          ...
# 2021-03-15 00:00:00+00:00  2021-03-16T00:00:00.000Z          158
# 2021-04-02 00:00:00+00:00  2021-04-03T00:00:00.000Z          152
# 2021-04-04 00:00:00+00:00  2021-04-05T00:00:00.000Z          150
# 2021-03-30 00:00:00+00:00  2021-03-31T00:00:00.000Z          132
# 2021-04-03 00:00:00+00:00  2021-04-04T00:00:00.000Z          128
#
# [365 rows x 2 columns]

# %%
responses = []
for response in tweepy.Paginator(client.get_all_tweets_count, query,
                                    start_time='2021-01-01T00:00:00Z',
                                 end_time='2022-01-01T00:00:00Z',
                                 granularity='year'):
    responses.append(response)
count_list = []
for resp in responses:
    count_list.extend(resp.data)
df7 = pd.DataFrame(count_list)
df7['start'] = pd.to_datetime(df7['start'])
df7 = df7.set_index('start')
df7.sort_values('tweet_count', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Input In [83], in <cell line: 2>()
#       1 responses = []
# ----> 2 for response in tweepy.Paginator(client.get_all_tweets_count, query,
#       3                                     start_time='2021-01-01T00:00:00Z',
#       4                                  end_time='2022-01-01T00:00:00Z',
#       5                                  granularity='year'):
#       6     responses.append(response)
#       7 count_list = []
#
# File ~\miniconda3\envs\foodsystems\lib\site-packages\tweepy\pagination.py:98, in PaginationIterator.__next__(self)
#      95 else:
#      96     self.kwargs["pagination_token"] = pagination_token
# ---> 98 response = self.method(*self.args, **self.kwargs)
#     100 self.previous_token = response.meta.get("previous_token")
#     101 self.next_token = response.meta.get("next_token")
#
# ...
